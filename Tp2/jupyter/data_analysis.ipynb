# %% [markdown]
# PARA AL MAYORIA DE ESTOS DATOS A MI ME PARECE LA MEJOR ELECCION HACER GRAFICOS DE DISTRIBUCION RESPECTO A LA PERFORMANCE
#
# CAMPANAS POR EL TCL

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("../../datos_tp2/datos.csv")
df.columns
# Out:
# Index(['strength', 'agility', 'expertise', 'endurance', 'health', 'height',
#        'performance', 'final_character_type', 'generation', 'N', 'K', 'M',
#        'threshold', 'character_type', 'selection_method_1',
#        'selection_method_2', 'selection_method_3', 'selection_method_4',
#        'crossing_method', 'mutation_method', 'new_generation_method', 'gene',
#        'A', 'B', 'p_m', 'Tc', 'T0', 'k', 'max_generations',
#        'max_generations_without_change', 'delta'],
#       dtype='object')

# %%
df.dtypes
# Out:
# strength                          float64
# agility                           float64
# expertise                         float64
# endurance                         float64
# health                            float64
# height                            float64
# performance                       float64
# final_character_type               object
# generation                          int64
# N                                   int64
# K                                   int64
# M                                   int64
# threshold                         float64
# character_type                     object
# selection_method_1                 object
# selection_method_2                 object
# selection_method_3                 object
# selection_method_4                 object
# crossing_method                    object
# mutation_method                    object
# new_generation_method              object
# gene                               object
# A                                 float64
# B                                 float64
# p_m                               float64
# Tc                                float64
# T0                                  int64
# k                                   int64
# max_generations                     int64
# max_generations_without_change      int64
# delta                             float64
# dtype: object

# %%
objectColumns = df.select_dtypes(include=['object']).columns
df[objectColumns] = df[objectColumns].astype('string')
df.dtypes
# Out:
# strength                                 float64
# agility                                  float64
# expertise                                float64
# endurance                                float64
# health                                   float64
# height                                   float64
# performance                              float64
# final_character_type              string[python]
# generation                                 int64
# N                                          int64
# K                                          int64
# M                                          int64
# threshold                                float64
# character_type                    string[python]
# selection_method_1                string[python]
# selection_method_2                string[python]
# selection_method_3                string[python]
# selection_method_4                string[python]
# crossing_method                   string[python]
# mutation_method                   string[python]
# new_generation_method             string[python]
# gene                              string[python]
# A                                        float64
# B                                        float64
# p_m                                      float64
# Tc                                       float64
# T0                                         int64
# k                                          int64
# max_generations                            int64
# max_generations_without_change             int64
# delta                                    float64
# dtype: object

# %%
df2 = pd.read_csv("../../datos_tp2/datos_cruce.csv")
df2.columns
# Out:
# Index(['strength', 'agility', 'expertise', 'endurance', 'health', 'height',
#        'performance', 'final_character_type', 'generation', 'N', 'K', 'M',
#        'threshold', 'character_type', 'selection_method_1',
#        'selection_method_2', 'selection_method_3', 'selection_method_4',
#        'crossing_method', 'mutation_method', 'new_generation_method', 'gene',
#        'A', 'B', 'p_m', 'Tc', 'T0', 'k', 'max_generations',
#        'max_generations_without_change', 'delta'],
#       dtype='object')

# %%
data_df = df
data_df_cruce = df2
len(df2)
# Out:
# 1843968

# %%
idx = df.groupby('final_character_type')['performance'].idxmax()
maxRows = df.loc[idx].drop(columns=['A', 'B', 'p_m', 'Tc', 'T0', 'k', 'max_generations',
                           'delta','selection_method_2', 'selection_method_3',
                             'selection_method_4','max_generations_without_change'])
maxRows
# Out:
#         strength    agility  expertise  endurance     health    height  \
# 11730  74.953247  74.495724   0.537370   0.003402   0.010257  1.917204
# 2860    0.026093   0.008759   0.647919  74.538989  74.778239  1.300054
# 2879   74.763948  74.444985   0.781777   0.002192   0.007098  1.916802
# 7325   74.783762  74.466763   0.731131   0.009471   0.008873  1.917250
#
#        performance                   final_character_type  generation    N  \
# 11730    61.874556       <class 'character_class.Archer'>         151  100
# 2860     58.202869     <class 'character_class.Defender'>         148  100
# 2879     55.002975  <class 'character_class.Infiltrator'>         136  100
# 7325     41.247892      <class 'character_class.Warrior'>         138  100
#
#         K   M  threshold character_type        selection_method_1  \
# 11730  60  30        0.7         archer  deterministic_tournament
# 2860   60  30        0.7       defender  deterministic_tournament
# 2879   60  30        0.7    infiltrator  deterministic_tournament
# 7325   60  30        0.7        warrior  deterministic_tournament
#
#       crossing_method   mutation_method new_generation_method    gene
# 11730         uniform  uniform_multigen       new_over_actual   items
# 2860        one_point  uniform_multigen       new_over_actual  height
# 2879        one_point  uniform_multigen       new_over_actual  height
# 7325     double_point  uniform_multigen       new_over_actual  height

# %%
idx = df2.groupby('final_character_type')['performance'].idxmax()
maxRows = df2.loc[idx].drop(columns=['A', 'B', 'p_m', 'Tc', 'T0', 'k', 'max_generations',
                           'delta','max_generations_without_change',
                           'threshold'])
maxRows
# Out:
#           strength    agility  expertise  endurance     health    height  \
# 988673   52.404699  41.315152  34.957149   8.466394  12.856605  1.902186
# 904004   16.873791  10.651235  31.305157  41.997929  49.171889  1.301173
# 60383    49.908359  45.781482  25.005978  12.883904  16.420277  1.917703
# 1231956  49.311590  48.007751  24.396763  12.969427  15.314469  1.936715
#
#          performance                   final_character_type  generation   N  \
# 988673     43.925380       <class 'character_class.Archer'>         100  10
# 904004     38.235099     <class 'character_class.Defender'>          59  10
# 60383      37.260024  <class 'character_class.Infiltrator'>          58  10
# 1231956    28.713273      <class 'character_class.Warrior'>          34  10
#
#          ...  M  character_type        selection_method_1  \
# 988673   ...  3          archer                  roulette
# 904004   ...  3        defender                   ranking
# 60383    ...  3     infiltrator                     elite
# 1231956  ...  3         warrior  deterministic_tournament
#
#                selection_method_2 selection_method_3  \
# 988673                      elite              elite
# 904004   probabilistic_tournament              elite
# 60383                     ranking          universal
# 1231956  deterministic_tournament            ranking
#
#                selection_method_4 crossing_method   mutation_method  \
# 988673   deterministic_tournament         uniform  uniform_multigen
# 904004   deterministic_tournament    double_point  uniform_multigen
# 60383                     ranking       one_point  uniform_multigen
# 1231956  deterministic_tournament         uniform  uniform_multigen
#
#         new_generation_method    gene
# 988673        new_over_actual   items
# 904004        new_over_actual   items
# 60383         new_over_actual  height
# 1231956       new_over_actual  height
#
# [4 rows x 21 columns]

# %% [markdown]
# Estas son las mejores configuraciones posibles para cada clase

# %%
df.groupby(['final_character_type','character_type'])['performance'].describe().sort_values('mean', ascending=False)
# Out:
#                                                        count       mean  \
# final_character_type                  character_type
# <class 'character_class.Archer'>      archer          4480.0  35.612239
# <class 'character_class.Infiltrator'> infiltrator     4480.0  32.378027
# <class 'character_class.Defender'>    defender        4480.0  31.369569
# <class 'character_class.Warrior'>     warrior         4480.0  24.723210
#
#                                                            std        min  \
# final_character_type                  character_type
# <class 'character_class.Archer'>      archer          8.993084  23.146642
# <class 'character_class.Infiltrator'> infiltrator     7.473567  21.862716
# <class 'character_class.Defender'>    defender        8.142416  17.960017
# <class 'character_class.Warrior'>     warrior         4.923357  17.960757
#
#                                                             25%        50%  \
# final_character_type                  character_type
# <class 'character_class.Archer'>      archer          29.446448  32.978714
# <class 'character_class.Infiltrator'> infiltrator     27.074566  30.457096
# <class 'character_class.Defender'>    defender        25.966340  28.783522
# <class 'character_class.Warrior'>     warrior         21.036575  23.779428
#
#                                                             75%        max
# final_character_type                  character_type
# <class 'character_class.Archer'>      archer          37.944546  61.874556
# <class 'character_class.Infiltrator'> infiltrator     34.564156  55.002975
# <class 'character_class.Defender'>    defender        33.463646  58.202869
# <class 'character_class.Warrior'>     warrior         26.107890  41.247892

# %% [markdown]
# Es notable que los arqueros son la clase con mejor performance (mayor impacto del cambio de las estadisticas)
#
# Parece buena idea utilizarlos como subgrupo para analizar el impacto de los metodos en mayor medida

# %%
filteredDf = df[df['final_character_type'] == "<class 'character_class.Archer'>"]
filteredDf_cruce = data_df_cruce[data_df_cruce['final_character_type'] == "<class 'character_class.Archer'>"]
filteredDf_cruce.groupby(['selection_method_1'])['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                             count       mean       std        min        25%  \
# selection_method_1
# elite                     65856.0  26.638081  2.478827  18.446704  24.907256
# deterministic_tournament  65856.0  26.232652  2.478454  17.334367  24.513311
# boltzmann                 65856.0  26.079983  2.512327  17.875655  24.334677
# ranking                   65856.0  26.050252  2.550044  16.426781  24.306590
# universal                 65856.0  25.910942  2.800976  14.239838  24.071124
# probabilistic_tournament  65856.0  25.904513  2.656415  14.511138  24.106741
# roulette                  65856.0  25.793079  2.816758  13.477315  23.949347
#
#                                 50%        75%        max
# selection_method_1
# elite                     26.457464  28.180657  39.254790
# deterministic_tournament  26.088078  27.803683  40.099523
# boltzmann                 25.904954  27.644800  41.097198
# ranking                   25.917573  27.654368  39.650272
# universal                 25.840267  27.683965  39.218029
# probabilistic_tournament  25.794418  27.599681  40.137984
# roulette                  25.735246  27.574842  43.925380

# %%
filteredDf.groupby(['selection_method_1'])['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                           count       mean        std        min        25%  \
# selection_method_1
# deterministic_tournament  640.0  42.268973  11.497154  26.906043  32.280433
# boltzmann                 640.0  42.209152  11.682026  27.496084  32.071321
# elite                     640.0  37.592251   7.489365  27.096197  31.670665
# ranking                   640.0  37.530925   3.899451  30.317129  34.701080
# probabilistic_tournament  640.0  33.544856   2.482652  27.504371  31.826754
# universal                 640.0  28.351849   1.884557  23.809217  26.908551
# roulette                  640.0  27.787665   1.801048  23.146642  26.547883
#
#                                 50%        75%        max
# selection_method_1
# deterministic_tournament  37.359325  55.078342  61.874556
# boltzmann                 36.567423  56.889334  60.635600
# elite                     34.674722  43.029467  58.524681
# ranking                   36.829905  39.858486  51.075848
# probabilistic_tournament  33.215478  35.058968  43.531843
# universal                 28.119372  29.567707  34.608407
# roulette                  27.677610  28.951603  33.861123

# %% [markdown]
# Notar la muy baja desviacion de ranking, torneo probabilistico, ruleta y ruleta_universal
#
# Boltzman y torneo deterministico tienen una distribucion muy parecida ( observar los fractiles )
#
# Veamos si en el resto de los datos se mantiene esta preferencia

# %%
data_df = filteredDf
data_df_cruce = filteredDf_cruce

# %%
group1 = ['universal', 'roulette', 'probabilistic_tournament']
group2 = ['elite', 'boltzmann', 'deterministic_tournament', 'ranking']



performance_min = data_df['performance'].min()
performance_max = data_df['performance'].max()
generation_min = data_df['generation'].min()
generation_max = data_df['generation'].max()
fig, axes = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

sns.histplot(data=data_df[data_df['selection_method_1'].isin(group1)], x="performance", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[0])
axes[0].set_title("Distribucion de la performance por metodo de seleccion (Grupo 1)")
axes[0].set_ylabel("Densidad")
axes[0].set_xlim([performance_min, performance_max])

sns.histplot(data=data_df[data_df['selection_method_1'].isin(group2)], x="performance", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[1])
axes[1].set_title("Distribucion de la performance por metodo de seleccion (Grupo 2)")
axes[1].set_xlabel("Performance")
axes[1].set_ylabel("Densidad")
axes[1].set_xlim([performance_min, performance_max])

plt.tight_layout()
plt.show()

# Create even less opaque plots with 'generation' graphs from different groups, one above the other
fig, axes = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

sns.histplot(data=data_df[data_df['selection_method_1'].isin(group1)], x="generation", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[0])
axes[0].set_title("Distribucion de la cantidad de generaciones por metodo de seleccion (Grupo 1)")
axes[0].set_ylabel("Densidad")
axes[0].set_xlim([generation_min, generation_max])

sns.histplot(data=data_df[data_df['selection_method_1'].isin(group2)], x="generation", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[1])
axes[1].set_title("Distribucion de la cantidad de generaciones por metodo de seleccion (Grupo 2)")
axes[1].set_xlabel("Cantidad de generaciones")
axes[1].set_ylabel("Densidad")
axes[1].set_xlim([generation_min, generation_max])

plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.groupby(['selection_method_1'])['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                            count       mean        std        min        25%  \
# selection_method_1
# deterministic_tournament  2560.0  36.660073  11.008785  20.613511  28.286262
# boltzmann                 2560.0  35.870792  11.013338  20.679057  27.638272
# ranking                   2560.0  32.852047   5.279730  22.082404  29.058957
# elite                     2560.0  32.624392   7.606053  20.693902  27.201879
# probabilistic_tournament  2560.0  29.516992   4.102562  20.924851  25.989084
# universal                 2560.0  25.010211   3.341901  18.203744  22.019842
# roulette                  2560.0  24.610821   3.250817  17.960017  21.651147
#
#                                 50%        75%        max
# selection_method_1
# deterministic_tournament  33.226331  44.586471  61.874556
# boltzmann                 31.999577  43.086093  60.635600
# ranking                   33.023733  36.265770  51.075848
# elite                     31.025624  36.763037  58.524681
# probabilistic_tournament  30.084085  32.395407  43.531843
# universal                 25.549390  27.300418  34.608407
# roulette                  25.117045  26.925153  33.861123

# %%
df_aux = df[((df['mutation_method'] == 'uniform_multigen') | 
            ((df['mutation_method'] == 'gene_mutation') & (df['gene'] == 'item')))]

df_aux.groupby(['selection_method_1','mutation_method'])['performance'].describe()
# Out:
#                                            count       mean       std  \
# selection_method_1       mutation_method
# boltzmann                uniform_multigen  640.0  47.584948  9.720652
# deterministic_tournament uniform_multigen  640.0  48.829011  8.397578
# elite                    uniform_multigen  640.0  40.728279  7.407323
# probabilistic_tournament uniform_multigen  640.0  30.777977  4.391160
# ranking                  uniform_multigen  640.0  36.019525  5.736220
# roulette                 uniform_multigen  640.0  24.852260  3.303481
# universal                uniform_multigen  640.0  25.241095  3.436230
#
#                                                  min        25%        50%  \
# selection_method_1       mutation_method
# boltzmann                uniform_multigen  24.322253  39.290370  51.062250
# deterministic_tournament uniform_multigen  26.525155  40.470392  51.004268
# elite                    uniform_multigen  25.181312  35.040951  40.804943
# probabilistic_tournament uniform_multigen  21.641502  27.227879  31.509827
# ranking                  uniform_multigen  23.832487  32.031557  36.635962
# roulette                 uniform_multigen  18.388539  21.840148  25.383175
# universal                uniform_multigen  18.870665  22.441465  25.684317
#
#                                                  75%        max
# selection_method_1       mutation_method
# boltzmann                uniform_multigen  55.158301  60.635600
# deterministic_tournament uniform_multigen  55.637527  61.874556
# elite                    uniform_multigen  46.428321  58.506322
# probabilistic_tournament uniform_multigen  33.870282  43.531843
# ranking                  uniform_multigen  39.992091  51.075848
# roulette                 uniform_multigen  27.135422  32.824729
# universal                uniform_multigen  27.525662  34.608407

# %%
group1 = ['universal', 'roulette', 'probabilistic_tournament', 'ranking']
group2 = ['elite', 'boltzmann', 'deterministic_tournament']



performance_min = df_aux['performance'].min()
performance_max = df_aux['performance'].max()
generation_min = df_aux['generation'].min()
generation_max = df_aux['generation'].max()
fig, axes = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

sns.histplot(data=df_aux[df_aux['selection_method_1'].isin(group1)], x="performance", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[0])
axes[0].set_title("Distribucion de la performance por metodo de seleccion (uniform y gene(item) mutations) (Grupo 1)")
axes[0].set_ylabel("Densidad")
axes[0].set_xlim([performance_min, performance_max])

sns.histplot(data=df_aux[df_aux['selection_method_1'].isin(group2)], x="performance", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[1])
axes[1].set_title("Distribucion de la performance por metodo de seleccion (uniform y gene(item) mutations) (Grupo 2)")
axes[1].set_xlabel("Performance")
axes[1].set_ylabel("Densidad")
axes[1].set_xlim([performance_min, performance_max])

plt.tight_layout()
plt.show()

# Create even less opaque plots with 'generation' graphs from different groups, one above the other
fig, axes = plt.subplots(2, 1, figsize=(12, 12), sharex=True)

sns.histplot(data=df_aux[df_aux['selection_method_1'].isin(group1)], x="generation", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[0])
axes[0].set_title("Distribucion de la cantidad de generaciones por metodo de seleccion (uniform y gene(item) mutations) (Grupo 1)")
axes[0].set_ylabel("Densidad")
axes[0].set_xlim([generation_min, generation_max])

sns.histplot(data=df_aux[df_aux['selection_method_1'].isin(group2)], x="generation", hue="selection_method_1", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes[1])
axes[1].set_title("Distribucion de la cantidad de generaciones por metodo de seleccion (uniform y gene(item) mutations) (Grupo 2)")
axes[1].set_xlabel("Cantidad de generaciones")
axes[1].set_ylabel("Densidad")
axes[1].set_xlim([generation_min, generation_max])

plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.groupby(['selection_method_1','mutation_method'])['performance'].describe()
# Out:
#                                             count       mean        std  \
# selection_method_1       mutation_method
# boltzmann                complete_mutation  640.0  28.252323   3.706228
#                          gene_mutation      640.0  36.256898  11.679813
#                          limited_multigen   640.0  31.389000   5.026273
#                          uniform_multigen   640.0  47.584948   9.720652
# deterministic_tournament complete_mutation  640.0  28.240987   3.864679
#                          gene_mutation      640.0  36.872185  11.759690
#                          limited_multigen   640.0  32.698107   5.150096
#                          uniform_multigen   640.0  48.829011   8.397578
# elite                    complete_mutation  640.0  27.998890   3.684022
#                          gene_mutation      640.0  31.806938   7.130828
#                          limited_multigen   640.0  29.963462   4.174348
#                          uniform_multigen   640.0  40.728279   7.407323
# probabilistic_tournament complete_mutation  640.0  29.208942   3.836436
#                          gene_mutation      640.0  28.734712   3.879629
#                          limited_multigen   640.0  29.346336   4.002663
#                          uniform_multigen   640.0  30.777977   4.391160
# ranking                  complete_mutation  640.0  31.246591   4.246197
#                          gene_mutation      640.0  31.935837   5.119482
#                          limited_multigen   640.0  32.206234   4.538825
#                          uniform_multigen   640.0  36.019525   5.736220
# roulette                 complete_mutation  640.0  24.688127   3.235386
#                          gene_mutation      640.0  24.340884   3.243119
#                          limited_multigen   640.0  24.562012   3.206647
#                          uniform_multigen   640.0  24.852260   3.303481
# universal                complete_mutation  640.0  25.019721   3.351056
#                          gene_mutation      640.0  24.862915   3.253920
#                          limited_multigen   640.0  24.917113   3.319112
#                          uniform_multigen   640.0  25.241095   3.436230
#
#                                                   min        25%        50%  \
# selection_method_1       mutation_method
# boltzmann                complete_mutation  21.127788  24.809050  28.659617
#                          gene_mutation      20.679057  27.250400  30.762965
#                          limited_multigen   21.524847  26.743215  31.835124
#                          uniform_multigen   24.322253  39.290370  51.062250
# deterministic_tournament complete_mutation  20.727507  24.815462  28.531485
#                          gene_mutation      20.613511  27.645426  31.766293
#                          limited_multigen   22.543168  28.925907  32.751471
#                          uniform_multigen   26.525155  40.470392  51.004268
# elite                    complete_mutation  21.347295  24.494262  28.327535
#                          gene_mutation      20.693902  26.761678  29.859337
#                          limited_multigen   21.995147  26.333990  30.322680
#                          uniform_multigen   25.181312  35.040951  40.804943
# probabilistic_tournament complete_mutation  21.413883  26.198953  29.714220
#                          gene_mutation      20.924851  25.145576  29.276357
#                          limited_multigen   21.676968  25.694001  30.025725
#                          uniform_multigen   21.641502  27.227879  31.509827
# ranking                  complete_mutation  22.082404  28.043949  31.979794
#                          gene_mutation      22.109773  28.260240  32.082497
#                          limited_multigen   22.548950  28.660689  32.971807
#                          uniform_multigen   23.832487  32.031557  36.635962
# roulette                 complete_mutation  18.111723  21.896805  25.094171
#                          gene_mutation      17.960017  21.012883  24.947135
#                          limited_multigen   17.960757  21.770875  25.042278
#                          uniform_multigen   18.388539  21.840148  25.383175
# universal                complete_mutation  18.458748  21.915283  25.639310
#                          gene_mutation      18.203744  21.870197  25.462348
#                          limited_multigen   18.420916  22.019842  25.381832
#                          uniform_multigen   18.870665  22.441465  25.684317
#
#                                                   75%        max
# selection_method_1       mutation_method
# boltzmann                complete_mutation  31.038857  40.142338
#                          gene_mutation      47.493872  60.271574
#                          limited_multigen   35.072179  46.626161
#                          uniform_multigen   55.158301  60.635600
# deterministic_tournament complete_mutation  31.048289  38.885881
#                          gene_mutation      49.038088  60.251765
#                          limited_multigen   36.193044  52.683784
#                          uniform_multigen   55.637527  61.874556
# elite                    complete_mutation  31.065240  38.264044
#                          gene_mutation      36.862343  58.524681
#                          limited_multigen   32.904496  42.922062
#                          uniform_multigen   46.428321  58.506322
# probabilistic_tournament complete_mutation  31.813805  40.009985
#                          gene_mutation      31.484426  38.490418
#                          limited_multigen   32.371595  40.488478
#                          uniform_multigen   33.870282  43.531843
# ranking                  complete_mutation  34.299287  43.205149
#                          gene_mutation      35.233474  50.152531
#                          limited_multigen   35.351348  44.952209
#                          uniform_multigen   39.992091  51.075848
# roulette                 complete_mutation  27.029682  33.861123
#                          gene_mutation      26.682283  31.758516
#                          limited_multigen   26.935332  33.055465
#                          uniform_multigen   27.135422  32.824729
# universal                complete_mutation  27.259841  33.995145
#                          gene_mutation      27.058784  33.616623
#                          limited_multigen   27.171459  33.996470
#                          uniform_multigen   27.525662  34.608407

# %% [markdown]
# Se mantiene

# %%
data_df_cruce.groupby('crossing_method')['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                     count       mean       std        min        25%  \
# crossing_method
# uniform          115248.0  26.537149  2.696710  14.796282  24.731931
# double_point     115248.0  26.049495  2.606236  14.079813  24.301029
# anular           115248.0  25.927755  2.604598  13.477315  24.168351
# one_point        115248.0  25.833888  2.554096  14.239838  24.123122
#
#                        50%        75%        max
# crossing_method
# uniform          26.434517  28.242595  43.925380
# double_point     25.942957  27.686723  40.137984
# anular           25.811823  27.577769  41.440852
# one_point        25.721968  27.428820  39.650272

# %% [markdown]
# El metodo de cruce parece tener un efecto nulo.
#
# Puede ser por el uso del mismo metodo de seleccion en las cuatro poblaciones de la muestra.

# %%
filteredDf.groupby('mutation_method')['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                     count       mean        std        min        25%  \
# mutation_method
# uniform_multigen   1120.0  41.937156  11.855771  23.809217  30.648244
# gene_mutation      1120.0  35.320638   9.560362  23.146642  28.914189
# limited_multigen   1120.0  33.489561   4.575586  24.308781  29.868342
# complete_mutation  1120.0  31.701600   3.298672  24.113114  29.501254
#
#                          50%        75%        max
# mutation_method
# uniform_multigen   40.495213  54.032720  61.874556
# gene_mutation      31.698432  38.041420  60.271574
# limited_multigen   33.757411  36.506327  52.683784
# complete_mutation  31.688541  33.723547  43.205149

# %% [markdown]
# Uniform es el mas performante por un notable margen (notar la mediana)

# %%
group = ['anular', 'uniform', 'one_point', 'double_point']



performance_min = data_df_cruce['performance'].min()
performance_max = data_df_cruce['performance'].max()
generation_min = data_df_cruce['generation'].min()
generation_max = data_df_cruce['generation'].max()
fig, axes = plt.subplots(1, 1, figsize=(12, 6), sharex=True)

# Obtener la paleta de colores
palette = sns.color_palette("husl", len(group))

# Crear un diccionario para mapear el método de cruce con su color
color_map = dict(zip(group, palette))

for crossing_method in group:
    subset = data_df_cruce[data_df_cruce['crossing_method'] == crossing_method]
    
    # Calcula el promedio y la mediana para 'performance'
    mean_performance = subset['performance'].mean()

    # Utilizar el color correspondiente al método de cruce
    axes.axvline(mean_performance, color=color_map[crossing_method], linestyle='-', label=f'Media de {crossing_method}')

sns.histplot(data=data_df_cruce[data_df_cruce['crossing_method'].isin(group)], x="performance", hue="crossing_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, palette=color_map, ax=axes)

axes.set_title("Distribución de la performance por método de cruce con promedio")
axes.set_ylabel("Densidad")
axes.set_xlim([performance_min, performance_max])

plt.tight_layout()
plt.show()

# Create even less opaque plots with 'generation' graphs from different groups, one above the other
fig, axes = plt.subplots(1, 1, figsize=(12, 6), sharex=True)

for crossing_method in group:
    subset = data_df_cruce[data_df_cruce['crossing_method'] == crossing_method]
    
    # Calcula el promedio y la mediana para 'performance'
    mean_performance = subset['generation'].mean()

    # Utilizar el color correspondiente al método de cruce
    axes.axvline(mean_performance, color=color_map[crossing_method], linestyle='-', label=f'Media de {crossing_method}')

sns.histplot(data=data_df_cruce[data_df_cruce['crossing_method'].isin(group)], x="generation", hue="crossing_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, palette=color_map, ax=axes)
axes.set_title("Distribución de la cantidad de generaciones por método de cruce con promedio")
axes.set_ylabel("Densidad")
axes.set_xlim([generation_min, generation_max])

plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Veamos si en todas las clases este resultado se mantiene

# %%
df.groupby('mutation_method')['performance'].describe().sort_values('mean',ascending=False)
# Out:
#                     count       mean        std        min        25%  \
# mutation_method
# uniform_multigen   4480.0  36.290442  11.227384  18.388539  26.889789
# gene_mutation      4480.0  30.687196   8.763040  17.960017  24.979143
# limited_multigen   4480.0  29.297466   5.256774  17.960757  25.208077
# complete_mutation  4480.0  27.807940   4.280907  18.111723  24.552805
#
#                          50%        75%        max
# mutation_method
# uniform_multigen   34.220734  44.046849  61.874556
# gene_mutation      28.451699  33.310576  60.271574
# limited_multigen   29.051843  33.160145  52.683784
# complete_mutation  27.730360  30.910941  43.205149

# %%
# No need to redefine data_df = df if data_df already contains the data

# Define the group and min-max for axes
group = ['uniform_multigen', 'limited_multigen','gene_mutation','complete_mutation']
performance_min = data_df['performance'].min()
performance_max = data_df['performance'].max()
generation_min = data_df['generation'].min()
generation_max = data_df['generation'].max()

# Initialize axes for the first plot
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

# Plot performance distribution
sns.histplot(data=data_df[data_df['mutation_method'].isin(group)], x="performance", hue="mutation_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes)
axes.set_title("Distribucion de la performance por metodo de mutacion")
axes.set_ylabel("Densidad")
axes.set_xlim([performance_min, performance_max])

plt.tight_layout()
plt.show()

# Initialize axes for the second plot
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

# Plot generation distribution
sns.histplot(data=data_df[data_df['mutation_method'].isin(group)], x="generation", hue="mutation_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, ax=axes)
axes.set_title("Distribucion de la cantidad de generaciones por metodo de mutacion")
axes.set_ylabel("Densidad")
axes.set_xlim([generation_min, generation_max])

plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Se mantiene
#
# Veamos ahora si existen variaciones de gene mutation que son mas performantes

# %%
df[df['mutation_method'] == 'gene_mutation'].groupby('gene')['performance'].describe().sort_values('mean',ascending=False)
# Out:
#          count       mean        std        min        25%        50%  \
# gene
# items   2240.0  34.392810  10.545203  17.960017  26.119514  31.958255
# height  2240.0  26.981581   3.865137  18.203744  24.040881  27.102182
#
#               75%        max
# gene
# items   40.509835  60.271574
# height  29.638307  40.413294

# %% [markdown]
# Mutar el Item presenta mucho mejores resultados, con una distribucion mas cercana a la observada en la mutacion uniforme
#
# Aunque no alcanza para justificar respecto a la uniforme por performance
#
# que hay de la cantidad de generaciones? (recurso de procesamiento)

# %%
df[df['mutation_method'] == 'gene_mutation'].groupby('gene')['generation'].describe().sort_values('mean',ascending=False)
# Out:
#          count       mean        std   min   25%   50%    75%    max
# gene
# items   2240.0  54.850000  15.051165  20.0  43.0  54.0  65.25  110.0
# height  2240.0  42.257589  28.697607  11.0  15.0  38.0  65.00  151.0

# %%
# Set the color palette to the one used before
filtered_data = data_df[data_df['mutation_method'] == 'gene_mutation']

# Plot performance distribution with the previous color palette
fig, axes = plt.subplots(1, 1, figsize=(12, 6))
sns.histplot(data=filtered_data, x="performance", hue="gene", element="step", stat="density", common_norm=False, fill=True, alpha=0.2, ax=axes)
axes.set_title("Distribucion de la performance por variación de 'gene' en 'gene_mutation'")
axes.set_ylabel("Densidad")
axes.set_xlim([performance_min, performance_max])
plt.tight_layout()
plt.show()

# Plot generation distribution with the previous color palette
fig, axes = plt.subplots(1, 1, figsize=(12, 6))
sns.histplot(data=filtered_data, x="generation", hue="gene", element="step", stat="density", common_norm=False, fill=True, alpha=0.2, ax=axes)
axes.set_title("Distribucion de la cantidad de generaciones por variación de 'gene' en 'gene_mutation'")
axes.set_ylabel("Densidad")
axes.set_xlim([generation_min, generation_max])
plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df[df['mutation_method'] == 'uniform_multigen'].groupby('gene')['generation'].describe().sort_values('mean',ascending=False)
# Out:
#          count       mean        std   min   25%   50%    75%    max
# gene
# height  2240.0  78.760714  22.622756  25.0  63.0  76.0  91.25  151.0
# items   2240.0  78.224554  22.631306  26.0  62.0  75.5  93.00  151.0

# %% [markdown]
# Observando unicamente la mutacion de gen sobre el Item (la unica caracteristica con impacto sobre la performance) podemos observar la ventaja de mutar el gen
#
# Mutar el gen resulta obtiene su resultado final en una notable menor cantidad de generaciones
#
# Menor promedio, mediana y desviacion!

# %%
filteredDf.groupby('new_generation_method')['performance'].describe()
# Out:
#                         count       mean       std        min        25%  \
# new_generation_method
# new_over_actual        2240.0  35.986287  9.617772  23.146642  29.189284
# use_all                2240.0  35.238190  8.306970  23.809217  29.617587
#
#                              50%        75%        max
# new_generation_method
# new_over_actual        33.042203  38.595980  61.874556
# use_all                32.877484  37.111852  61.506866

# %%
df.groupby('new_generation_method')['performance'].describe()
# Out:
#                         count       mean       std        min        25%  \
# new_generation_method
# new_over_actual        8960.0  31.364612  9.068931  17.960017  25.199275
# use_all                8960.0  30.676910  7.905392  18.182929  25.342402
#
#                              50%        75%        max
# new_generation_method
# new_over_actual        29.147078  34.821367  61.874556
# use_all                29.178342  33.537372  61.506866

# %%
filteredDf.groupby('new_generation_method')['generation'].describe()
# Out:
#                         count       mean        std   min   25%   50%    75%  \
# new_generation_method
# new_over_actual        2240.0  66.479464  29.321866  12.0  43.0  67.0  87.25
# use_all                2240.0  56.169196  26.050462  12.0  34.0  56.0  75.00
#
#                          max
# new_generation_method
# new_over_actual        151.0
# use_all                145.0

# %%
# No need to redefine data_df = df if data_df already contains the data

# Define the group and min-max for axes
group = ['use_all', 'new_over_actual']
performance_min = data_df['performance'].min()
performance_max = data_df['performance'].max()
generation_min = data_df['generation'].min()
generation_max = data_df['generation'].max()

# Initialize axes for the first plot
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

# Obtener la paleta de colores
palette = sns.color_palette("husl", len(group))

# Crear un diccionario para mapear el método de cruce con su color
color_map = dict(zip(group, palette))

for crossing_method in group:
    subset = data_df[data_df['new_generation_method'] == crossing_method]
    
    # Calcula el promedio y la mediana para 'performance'
    mean_performance = subset['performance'].mean()

    # Utilizar el color correspondiente al método de cruce
    axes.axvline(mean_performance, color=color_map[crossing_method], linestyle='-', label=f'Media de {crossing_method}')

# Plot performance distribution
sns.histplot(data=data_df[data_df['new_generation_method'].isin(group)], x="performance", hue="new_generation_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, palette=color_map, ax=axes)
axes.set_title("Distribucion de la performance por metodo de reemplazo con promedio")
axes.set_ylabel("Densidad")
axes.set_xlim([performance_min, performance_max])


plt.tight_layout()
plt.show()

# Initialize axes for the second plot
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

for crossing_method in group:
    subset = data_df[data_df['new_generation_method'] == crossing_method]
    
    # Calcula el promedio y la mediana para 'performance'
    mean_performance = subset['generation'].mean()
    # Utilizar el color correspondiente al método de cruce
    axes.axvline(mean_performance, color=color_map[crossing_method], linestyle='-', label=f'Media de {crossing_method}')

# Plot generation distribution
sns.histplot(data=data_df[data_df['new_generation_method'].isin(group)], x="generation", hue="new_generation_method", element="step", stat="density", common_norm=False, fill=True, alpha=0.1, palette=color_map, ax=axes)
axes.set_title("Distribucion de la cantidad de generaciones por metodo de reemplazo con promedio")
axes.set_ylabel("Densidad")
axes.set_xlim([generation_min, generation_max])


plt.tight_layout()
plt.show()
# Out:
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/adol/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# NEW GENERATION METHOD:
#
# Mismos resultados de performance, o por lo menos indistinguibles con el analisis.
#
# Menor uso de recursos por parte de use_all
